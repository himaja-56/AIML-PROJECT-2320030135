# %% [markdown]
# <a href="https://colab.research.google.com/github/himaja-56/AIML-PROJECT-2320030135/blob/main/ToolsForDataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Science Tools**

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Objectives:
#
# 1. List popular languages for Data Science
# 2. Identify commonly used libraries used by Data Scientists
# 3. Describe development environment open source tools used in data science
# 4. Evaluate arithmetic expressions in Python

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Scala
# 6. Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy - Fundamental library for numerical computing.
# 2. Pandas - Essential library for data manipulation and analysis.
# 3. Matplotlib - Primary plotting library for creating static, animated, and interactive visualizations
# 4. Scikit-learn - Comprehensive machine learning library with algorithms for classification, regression, and clustering
# 5. SciPy - Scientific computing library that extends NumPy with additional mathematical functions and algorithms

# %% [markdown]
# Data Science Tools
# 1. Jupyter Notebooks
# 2. Apache Spark
# 3. MLflow

# %% [markdown]
# Arithmetic Example
# (3*4)+5

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Author Name**
#
# Himaja Sadhu
